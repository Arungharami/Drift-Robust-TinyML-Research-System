# %% [markdown]
# # Environment and reproducibility
# Records kernel evidence, hardware visibility, package versions, Git commit, and deterministic seed. Run this notebook first.

# %%
from pathlib import Path
from src.utils.reproducibility import capture_environment
environment = capture_environment(Path('../results/reproducibility/environment.json'), seed=42)
{k: environment[k] for k in ('in_colab','python','platform','gpu','git_commit','seed')}
