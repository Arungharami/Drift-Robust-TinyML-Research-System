# %% [markdown]
# # Temporal adaptation and IID diagnostic
# Expanding-window retraining uses historical batches only. IID results are `DIAGNOSTIC_ONLY` and are never treated as the primary temporal result.

# %%
from pathlib import Path
import pandas as pd
root = Path('..')
expanding = pd.read_csv(root/'results/baselines/expanding_vs_fixed.csv')
iid_gap = pd.read_csv(root/'results/baselines/iid_generalization_gap.csv')
correlations = pd.read_csv(root/'results/baselines/drift_performance_correlations.csv')
expanding, iid_gap, correlations

# %%
from IPython.display import Image, display
for n in (11, 12, 13, 14, 15):
    matches = list((root/'results/figures').glob(f'figure_{n}_*.png'))
    if matches: display(Image(filename=str(matches[0])))
