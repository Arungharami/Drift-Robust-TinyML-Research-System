# %% [markdown]
# # Classical chronological baselines
# Primary evidence uses `FIXED_ORIGIN_B1`: preprocessing and models see batch 1 only; batches 2–10 are evaluated separately. Metrics below are loaded from raw-prediction-derived artifacts.

# %%
from pathlib import Path
import pandas as pd
root = Path('..')
metrics = pd.read_csv(root/'results/baselines/fixed_origin_metrics.csv')
classes = pd.read_csv(root/'results/baselines/class_performance_by_batch.csv')
predictions = root/'results/baselines/predictions/fixed_origin_b1_predictions.csv'
metrics, predictions

# %%
from IPython.display import Image, display
for n in (6, 7, 8, 9, 10):
    matches = list((root/'results/figures').glob(f'figure_{n}_*.png'))
    if matches: display(Image(filename=str(matches[0])))
